# %%
import numpy as np

# %%
array1=np.array([22,55,61])
print(array1)
# Out:
# [22 55 61]

# %%
array2=np.array([[44,55,20,],[21,56,12]])
print(array2)
# Out:
# [[44 55 20]
#  [21 56 12]]

# %%
(array1[~(array1<5)])
# Out:
# array([22, 55, 61])

# %%
array1[(array1>5)& (array1 %2 == 0)]
# Out:
# array([22])

# %%
array1[array1 %2 == 0]
# Out:
# array([22])

# %%
array1[(array1>5)| (array1 %2 == 0)]
# Out:
# array([22, 55, 61])

# %%
array1[(array1>5)& ~(array1 %2 == 0)]
# Out:
# array([55, 61])

# %%
array1[-2]
# Out:
# np.int64(55)

# %%
array1[0:2]
# Out:
# array([22, 55])

# %%
array2[0,1]
# Out:
# np.int64(55)

# %%
array2[0:,0:2]
# Out:
# array([[44, 55],
#        [21, 56]])

# %%
array2[0:,2]
# Out:
# array([20, 12])

# %%
array2[0,1:]
# Out:
# array([55, 20])

# %%
array2
# Out:
# array([[44, 55, 20],
#        [21, 56, 12]])

# %%
array3=np.array([[[1,2,3,4],[5,4,8,9],[7,8,1,4]],[[1,4,7,8],[1,2,3,4],[0,4,8,9]]])
print(array3)
# Out:
# [[[1 2 3 4]
#   [5 4 8 9]
#   [7 8 1 4]]
#
#  [[1 4 7 8]
#   [1 2 3 4]
#   [0 4 8 9]]]

# %%
array3[0,2,2]
# Out:
# np.int64(1)

# %%
array3[0:2,1:3,1:]
# Out:
# array([[[4, 8, 9],
#         [8, 1, 4]],
#
#        [[2, 3, 4],
#         [4, 8, 9]]])

# %%
array1=np.array([22,55,61])
print(array1)
# Out:
# [22 55 61]

# %%
array0=np.array([[44,88,99,],[23,41,33]])
print(array0)
# Out:
# [[44 88 99]
#  [23 41 33]]

# %%
array0[(array0>5)& ~(array0 % 2==0)]
# Out:
# array([99, 23, 41, 33])

# %%
array0[array0 % 2== 0]
# Out:
# array([44, 88])

# %%
array0[(array0>5)|(array0 % 2==0)]
# Out:
# array([44, 88, 99, 23, 41, 33])

# %%
array0[(array0>5)& ~(array0 % 2==0)]
# Out:
# array([99, 23, 41, 33])

# %%
array0[-2]
# Out:
# array([44, 88, 99])

# %%
array0[0:2]
# Out:
# array([[44, 88, 99],
#        [23, 41, 33]])

# %%
array0[0,1]
# Out:
# np.int64(88)

# %%
array0[0:,0:2]
# Out:
# array([[44, 88],
#        [23, 41]])

# %%
array0[0:,2]
# Out:
# array([99, 33])

# %%
array0[0,1:]
# Out:
# array([88, 99])

# %%
array01=np.array([[[21,23,23],[10,55,33],[11,22,33]],[[11,22,33],[12,33,45],[10,41,55]]])
print(array01)
# Out:
# [[[21 23 23]
#   [10 55 33]
#   [11 22 33]]
#
#  [[11 22 33]
#   [12 33 45]
#   [10 41 55]]]

# %%
array01[0,2,2]
# Out:
# np.int64(33)

# %%
array01[0:2,1:3,1:]
# Out:
# array([[[55, 33],
#         [22, 33]],
#
#        [[33, 45],
#         [41, 55]]])

# %%
#array2[[0,1],[0,1]]
# Out:
# array([44, 56])

# %%
array2
# Out:
# array([[44, 55, 20],
#        [21, 56, 12]])

# %%
array1.sum()
# Out:
# np.int64(138)

# %%
array2.sum()
# Out:
# np.int64(208)

# %%
array2.sum(axis=0)
# Out:
# array([ 65, 111,  32])

# %%
array2.sum(axis=1)
# Out:
# array([119,  89])

# %%
array2.prod()
# Out:
# np.int64(683020800)

# %%
array1.min()
# Out:
# np.int64(22)

# %%
array1.max()
# Out:
# np.int64(61)

# %%
np.log(array1)
# Out:
# array([3.09104245, 4.00733319, 4.11087386])

# %%
np.round(array1)
# Out:
# array([22, 55, 61])

# %%
np.exp(array1)
# Out:
# array([3.58491285e+09, 7.69478527e+23, 3.10429794e+26])

# %%
#statistical functions
np.mean(array1)
# Out:
# np.float64(46.0)

# %%
np.median(array1)
# Out:
# np.float64(55.0)

# %%
np.std(array1)
# Out:
# np.float64(17.146428199482248)

# %%
np.var(array1)
# Out:
# np.float64(294.0)

# %%
np.percentile(array1,30)
# Out:
# np.float64(41.8)

# %%
np.quantile(array1,0.30)
# Out:
# np.float64(41.8)

# %%
array1.sort()

# %%
array1
# Out:
# array([22, 55, 61])

# %%
array2.sort()

# %%
array2
# Out:
# array([[20, 44, 55],
#        [12, 21, 56]])

# %%
array1.argmin()
# Out:
# np.int64(0)

# %%
array1.argmax()
# Out:
# np.int64(2)

# %%
array1.argsort()
# Out:
# array([0, 1, 2])

# %%
ar=np.array([56,78,23])

# %%
ar.argsort()
# Out:
# array([2, 0, 1])

# %%
ar.sort()

# %%
ar
# Out:
# array([23, 56, 78])

# %%
ar.argsort()
# Out:
# array([0, 1, 2])

# %%
array2
# Out:
# array([[20, 44, 55],
#        [12, 21, 56]])

# %%
array2.argmin()
# Out:
# np.int64(3)
